# %% [markdown]
# # Load Data

# %%
! gdown --id 15RmYQObBdyYOZ1ryLVw5fZvvLv8UNKDw
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=15RmYQObBdyYOZ1ryLVw5fZvvLv8UNKDw
# To: /content/creditcard.csv
# 100% 103M/103M [00:01<00:00, 71.1MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# **EDA**

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='Class', data=data)

# Annotate each bar with its count
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha = 'center', va = 'center',
                   xytext = (0, 9),
                   textcoords = 'offset points')

plt.title('Distribution of Classes')
# Save the plot as an image file (PNG)
plt.savefig('visualization1.png')
plt.show()

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.isna().sum().any()
# Out:
# False

# %%
data.hist(bins=30, figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
corr = data.corr()  # Compute the correlation matrix

plt.figure(figsize=(30,27))
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap')
# Save the plot as an image file (PNG)
plt.savefig('visualization2.png')
plt.show()

# %% [markdown]
# # **Insight**
# **There is no corr relation between the variables**

# %%
# For numerical variables, visualize box plots to identify outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=data.drop(columns=['Time', 'Class']))
plt.title("Box Plot of Numerical Variables")
# Save the plot as an image file (PNG)
plt.savefig('visualization3.png')
plt.show()

# %% [markdown]
# # **Feature** **Engineering**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data['Time'] = pd.to_datetime(data['Time'])

# %%
data.head()
# Out:
#                            Time        V1        V2        V3        V4  \
# 0 1970-01-01 00:00:00.000000000 -1.359807 -0.072781  2.536347  1.378155
# 1 1970-01-01 00:00:00.000000000  1.191857  0.266151  0.166480  0.448154
# 2 1970-01-01 00:00:00.000000001 -1.358354 -1.340163  1.773209  0.379780
# 3 1970-01-01 00:00:00.000000001 -0.966272 -0.185226  1.792993 -0.863291
# 4 1970-01-01 00:00:00.000000002 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8        V9  ...       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
#
# ...

# %% [markdown]
# # **Normalize numerical features**

# %%
from sklearn.preprocessing import StandardScaler

# Normalize numerical features
numerical_features = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
                      'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19',
                      'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
                      'Amount']

scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# %% [markdown]
# # **P C A**

# %%
from sklearn.decomposition import PCA

# Dimensionality reduction with PCA
pca = PCA(n_components=10)  # Choose the number of components based on explained variance
data_pca = pca.fit_transform(data[numerical_features])

# %%
X = data.drop(columns=['Class','Time'])
y = data['Class']

# %% [markdown]
# # **Under Sampling**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
normal_sample=normal.sample(n=473)
new_data = pd.concat([normal_sample,fraud],ignore_index=True)
new_data['Class'].value_counts()
# Out:
# Class
# 1    492
# 0    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#                            Time        V1        V2        V3        V4  \
# 0 1970-01-01 00:00:00.000076478  0.554659 -0.098199  0.489983  1.056511
# 1 1970-01-01 00:00:00.000024046 -0.239777  0.596521  1.037969  0.975028
# 2 1970-01-01 00:00:00.000171423  1.059238  0.162187 -1.093564  0.289974
# 3 1970-01-01 00:00:00.000151678 -0.336824  0.459512  1.429500  0.058192
# 4 1970-01-01 00:00:00.000140328  0.012661  0.112938  0.514446 -0.607254
#
#          V5        V6        V7        V8        V9  ...       V21       V22  \
# 0 -0.309755  0.370268 -0.300958  0.171788  0.853063  ... -0.128312  0.030433
# 1  0.364431  0.208091  0.450668 -0.095248  1.318674  ... -0.368536 -0.130732
# 2  0.385199 -0.649222  0.231027 -0.269950  0.244213  ... -0.470775 -1.126512
# 3 -0.124729 -0.006287 -0.167502  0.235785  0.189959  ...  0.335102  0.983582
# 4 -0.040075 -0.014121  0.379031 -0.010612  0.652598  ...  0.348120  1.169610
#
# ...

# %% [markdown]
# # **Model Training & Selection with Hyperparameter Tuning**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # **Logistic Regression Model**

# %%
# Create an instance of the Logistic Regression classifier
logistic_regression = LogisticRegression()

# %%
# Perform cross-validation
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(logistic_regression, X, y, cv=5)  # 5-fold cross-validation

# Print cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean CV accuracy:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.99899933 0.99933289 0.99894665 0.99931532 0.99903443]
# Mean CV accuracy: 0.9991257234521111

# %%
# Define the parameter grid
param_grid = {
    'penalty': ['l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]
}
n_iter = min(6, 10)

# %%
# Instantiate the Randomized Search with the Logistic Regression classifier and parameter grid
Randomized_Search_lr = RandomizedSearchCV(estimator=logistic_regression, param_distributions=param_grid, cv=5, scoring='accuracy', error_score='raise')

# %%
Randomized_Search_lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, error_score='raise', estimator=LogisticRegression(),
#                    param_distributions={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                                         'penalty': ['l2']},
#                    scoring='accuracy')

# %%
# Get the best parameters and the best estimator
best_params_lr = Randomized_Search_lr.best_params_
best_estimator_lr = Randomized_Search_lr.best_estimator_

print("Best Parameters for Logistic Regression:", best_params_lr)
print("Best Estimator for Logistic Regression:", best_estimator_lr)
# Out:
# Best Parameters for Logistic Regression: {'penalty': 'l2', 'C': 10}
# Best Estimator for Logistic Regression: LogisticRegression(C=10)

# %%
y_prediction = best_estimator_lr.predict(X_test)
y_proba = best_estimator_lr.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
accuracy_score_lr = accuracy_score(y_test,y_prediction)
precision = precision_score(y_test, y_prediction)
recall = recall_score(y_test, y_prediction)
f1 = f1_score(y_test, y_prediction)
roc_auc = roc_auc_score(y_test, y_proba)

# %%
print("accuracy_score:", accuracy_score_lr)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("ROC-AUC:", roc_auc)
# Out:
# accuracy_score: 0.9991222218320986
# Precision: 0.8636363636363636
# Recall: 0.5816326530612245
# F1-score: 0.6951219512195121
# ROC-AUC: 0.976081850860772

# %% [markdown]
# # **Plotting Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
cm = confusion_matrix(y_test, y_prediction)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization4.png')
plt.show()

# %%
from sklearn.model_selection import cross_val_score, learning_curve, validation_curve
from sklearn.metrics import accuracy_score
import numpy as np

# %%
# Define your models
models = {
    'Logistic Regression': LogisticRegression(),
}

# %%
# Learning Curves
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

    plt.legend(loc="best")
    return plt

for name, model in models.items():
    plot_learning_curve(model, f"Learning Curve ({name})", X, y, cv=5, n_jobs=-1)
# Save the plot as an image file (PNG)
plt.savefig('visualization3.png')

# %% [markdown]
# # **Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
# Create the classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
# Define the parameter grid
param_grid = {
    'max_depth': [3, 5],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required at each leaf node
}
# Create RandomizedSearchCV object
randomized_search_dt = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
# Fit the GridSearchCV object to the training data
randomized_search_dt.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [3, 5],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10]},
#                    scoring='accuracy')

# %%
# Get the best parameters and best score
best_params = randomized_search_dt.best_params_
best_estimator_dt = randomized_search_dt.best_estimator_

print("Best Parameters:", best_params)
print("Best Score:", best_estimator_dt)
# Out:
# Best Parameters: {'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 5}
# Best Score: DecisionTreeClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=5,
#                        random_state=42)

# %%
y_prediction_dt = best_estimator_dt.predict(X_test)
y_proba = best_estimator_dt.predict_proba(X_test)[:, 1]

# %%
accuracy_score_dt = accuracy_score(y_test,y_prediction_dt)
precision_dt = precision_score(y_test, y_prediction_dt)
recall_dt = recall_score(y_test, y_prediction_dt)
f1_dt = f1_score(y_test, y_prediction_dt)
roc_auc_dt = roc_auc_score(y_test, y_proba)

# %%
print("accuracy_score:", accuracy_score_dt)
print("Precision:", precision_dt)
print("Recall:", recall_dt)
print("F1-score:", f1_dt)
print("ROC-AUC:", roc_auc_dt)
# Out:
# accuracy_score: 0.9994908886626171
# Precision: 0.896551724137931
# Recall: 0.7959183673469388
# F1-score: 0.8432432432432432
# ROC-AUC: 0.9283975443019076

# %%
# Perform cross-validation
cv_scores = cross_val_score(dt_classifier, X, y, cv=5)  # 5-fold cross-validation

# Print cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean CV accuracy:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.99782311 0.99931533 0.99713839 0.99861309 0.9989642 ]
# Mean CV accuracy: 0.9983708251665415

# %% [markdown]
# # **Confusion Matrix**

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_prediction_dt)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Decision Tree Classifier")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization4.png')
plt.show()

# %%
# Define your models
models = {
    'DecisionTreeClassifier': DecisionTreeClassifier()
    }

# %%
# Learning Curves
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

    plt.legend(loc="best")
    return plt

for name, model in models.items():
    plot_learning_curve(model, f"Learning Curve ({name})", X, y, cv=5, n_jobs=-1)
# Save the plot as an image file (PNG)
plt.savefig('visualization5.png')

# %% [markdown]
# # **Random Forest Model**

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Perform cross-validation to evaluate model performance
cv_scores = cross_val_score(rf_classifier, X_train, y_train, cv=5)

# Train the model on the entire training set
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the model on the test set
test_accuracy = rf_classifier.score(X_test, y_test)

# Print cross-validation scores and test accuracy
print("Cross-Validation Scores:", cv_scores)
print("Average CV Score:", np.mean(cv_scores))
print("Test Accuracy:", test_accuracy)
# Out:
# Cross-Validation Scores: [0.99951722 0.99947333 0.99949527 0.99953916 0.99956111]
# Average CV Score: 0.9995172156509909
# Test Accuracy: 0.9995611109160493

# %%
# Predictions on the test set
rf_prediction = rf_classifier.predict(X_test)

# Accuracy
rf_accuracy_score = accuracy_score(y_test, rf_prediction)

# Precision
rf_precision = precision_score(y_test, rf_prediction, average='weighted')

# Recall
rf_recall = recall_score(y_test, rf_prediction, average='weighted')

# F1 score
rf_f1 = f1_score(y_test, rf_prediction, average='weighted')

y_proba = rf_classifier.predict_proba(X_test)[:, 1]
rf_roc_auc = roc_auc_score(y_test, y_proba)

# %%
# Print the metrics
print("Test Accuracy:", rf_accuracy_score)
print("Precision:", rf_precision)
print("Recall:", rf_recall)
print("F1 Score:", rf_f1)
print("ROC AUC Score:", rf_roc_auc)
# Out:
# Test Accuracy: 0.9995611109160493
# Precision: 0.9995516842152548
# Recall: 0.9995611109160493
# F1 Score: 0.999534818084207
# ROC AUC Score: 0.9526124092715308

# %% [markdown]
# # **confusion matrix**

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, rf_prediction)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Random Forest Classifier")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization6.png')
plt.show()

# %%
final_data = pd.DataFrame({'Models':['Logistic Regression','Decision Tree','RandomForest'],
              "ACCURACY":[accuracy_score(y_test,y_prediction)*100,
                     accuracy_score(y_test,y_prediction_dt)*100,
                     accuracy_score(y_test,rf_prediction)*100
                    ]})
final_data
# Out:
#                 Models   ACCURACY
# 0  Logistic Regression  99.912222
# 1        Decision Tree  99.949089
# 2         RandomForest  99.956111

# %%
# Assuming final_data is a DataFrame containing 'Models' and 'ACCURACY' columns
sns.barplot(x=final_data['Models'], y=final_data['ACCURACY'])
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Models')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
# Save the plot as an image file (PNG)
plt.savefig('visualization6.png')
plt.show()

# %% [markdown]
# # **Comaprison of the Model Scores**

# %%
# Define model names
model_names = ['Logistic Regression', 'Decision Tree', 'Random Forest']

# Define performance metrics for each model
precisions = [precision, precision_dt, rf_precision]
recalls = [recall, recall_dt, rf_recall]
f1_scores = [f1, f1_dt, rf_f1]
roc_auc_scores = [roc_auc, roc_auc_dt, rf_roc_auc]

# %%
# Plotting
fig, axes = plt.subplots(2, 2, figsize=(16, 15))

# Precision
axes[0, 0].bar(model_names, precisions, color='skyblue')
axes[0, 0].set_title('Precision')
axes[0, 0].set_ylabel('Precision')
axes[0, 0].set_ylim(0, 1)

# Recall
axes[0, 1].bar(model_names, recalls, color='lightgreen')
axes[0, 1].set_title('Recall')
axes[0, 1].set_ylabel('Recall')
axes[0, 1].set_ylim(0, 1)

# F1-score
axes[1, 0].bar(model_names, f1_scores, color='salmon')
axes[1, 0].set_title('F1-score')
axes[1, 0].set_ylabel('F1-score')
axes[1, 0].set_ylim(0, 1)

# ROC-AUC
axes[1, 1].bar(model_names, roc_auc_scores, color='gold')
axes[1, 1].set_title('ROC-AUC')
axes[1, 1].set_ylabel('ROC-AUC')
axes[1, 1].set_ylim(0, 1)

# Adjust layout
plt.tight_layout()
# Save the plot as an image file (PNG)
plt.savefig('visualization7.png')
plt.show()

# %% [markdown]
# # **Over Sampling**

# %%
X = data.drop(columns=['Class','Time'])
y = data['Class']

# %%
from imblearn.over_sampling import SMOTE
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # **Logistic Regression classifier**

# %%
# Create an instance of the Logistic Regression classifier
logistic_regression = LogisticRegression()

# Define the parameter grid
param_grid = {
    'penalty': ['l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
# Instantiate the RandomizedSearchCV with the Logistic Regression classifier and parameter grid
random_search_lr = RandomizedSearchCV(estimator=logistic_regression, param_distributions=param_grid, cv=5, scoring='accuracy', error_score='raise')

# %%
random_search_lr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, error_score='raise', estimator=LogisticRegression(),
#                    param_distributions={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                                         'penalty': ['l2']},
#                    scoring='accuracy')

# %%
# Get the best parameters and the best estimator
best_params_lr = random_search_lr.best_params_
best_estimator_lr = random_search_lr.best_estimator_

print("Best Parameters for Logistic Regression:", best_params_lr)
print("Best Estimator for Logistic Regression:", best_estimator_lr)
# Out:
# Best Parameters for Logistic Regression: {'penalty': 'l2', 'C': 10}
# Best Estimator for Logistic Regression: LogisticRegression(C=10)

# %%
y_prediction = best_estimator_lr.predict(X_test)
y_proba = best_estimator_lr.predict_proba(X_test)[:, 1]

# %%
accuracy_score_lr = accuracy_score(y_test,y_prediction)
precision = precision_score(y_test, y_prediction)
recall = recall_score(y_test, y_prediction)
f1 = f1_score(y_test, y_prediction)
roc_auc = roc_auc_score(y_test, y_proba)

# %%
print("accuracy_score:", accuracy_score_lr)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("ROC-AUC:", roc_auc)
# Out:
# accuracy_score: 0.9457907602483161
# Precision: 0.9735502991668065
# Recall: 0.9167017691659646
# F1-score: 0.944271186440678
# ROC-AUC: 0.9890216922621101

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_prediction)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Logistic Regression Classifier Over Sampling")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization8.png')
plt.show()

# %%
# Define your models
models = {
    'Logistic Regression': LogisticRegression(),
}
# Cross-validation to assess model performance
for name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5)  # 5-fold cross-validation
    print(f'{name}: Mean Accuracy - {np.mean(scores)}, Std Dev - {np.std(scores)}')
# Out:
# Logistic Regression: Mean Accuracy - 0.9991257234521111, Std Dev - 0.00016446419470675041

# %%
# Learning Curves
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

    plt.legend(loc="best")
    return plt

for name, model in models.items():
    plot_learning_curve(model, f"Learning Curve ({name})", X, y, cv=5, n_jobs=-1)
# Save the plot as an image file (PNG)
plt.savefig('visualization9.png')

# %% [markdown]
# # **Decision Tree Classifier**

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

# %%
# Define the parameter grid
param_grid = {
    'max_depth': [3, 5, 7],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required at each leaf node
}
# Create RandomizedSearchCV object
random_search_dt = RandomizedSearchCV(estimator=dt_classifier, param_distributions=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# %%
# Train model
random_search_dt.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [3, 5, 7],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10]},
#                    scoring='accuracy')

# %%
# Get the best parameters and best score
best_params = random_search_dt.best_params_
best_estimator_dt = random_search_dt.best_estimator_

print("Best Parameters:", best_params)
print("Best Score:", best_estimator_dt)
# Out:
# Best Parameters: {'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 7}
# Best Score: DecisionTreeClassifier(max_depth=7, min_samples_leaf=2, random_state=42)

# %%
y_prediction_dt = best_estimator_dt.predict(X_test)
y_proba = best_estimator_dt.predict_proba(X_test)[:, 1]

# %%
accuracy_score_dt = accuracy_score(y_test,y_prediction_dt)
precision_dt = precision_score(y_test, y_prediction_dt)
recall_dt = recall_score(y_test, y_prediction_dt)
f1_dt = f1_score(y_test, y_prediction_dt)
roc_auc_dt = roc_auc_score(y_test, y_proba)

# %%
print("accuracy_score:", accuracy_score_dt)
print("Precision:", precision_dt)
print("Recall:", recall_dt)
print("F1-score:", f1_dt)
print("ROC-AUC:", roc_auc_dt)
# Out:
# accuracy_score: 0.9704201325994056
# Precision: 0.9795177274516117
# Recall: 0.9610537770289245
# F1-score: 0.9701979127908006
# ROC-AUC: 0.9914476991316847

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_prediction_dt)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Decision Tree Classifier- Over Sampling")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization 10.png')
plt.show()

# %%
# Define your models
models = {
    'DecisionTreeClassifier': DecisionTreeClassifier()
    }

# %%
# Learning Curves
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

    plt.legend(loc="best")
    return plt

for name, model in models.items():
    plot_learning_curve(model, f"Learning Curve ({name})", X, y, cv=5, n_jobs=-1)
# Save the plot as an image file (PNG)
plt.savefig('visualization 11.png')

# %% [markdown]
# # **Random Forest Model**

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Perform cross-validation to evaluate model performance
cv_scores = cross_val_score(rf_classifier, X_train, y_train, cv=5)

# Train the model on the entire training set
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the model on the test set
test_accuracy = rf_classifier.score(X_test, y_test)

# Print cross-validation scores and test accuracy
print("Cross-Validation Scores:", cv_scores)
print("Average CV Score:", np.mean(cv_scores))
print("Test Accuracy:", test_accuracy)
# Out:
# Cross-Validation Scores: [0.99985711 0.99990108 0.99982414 0.99991207 0.99984612]
# Average CV Score: 0.999868103991207
# Test Accuracy: 0.9998944832316269

# %%
# Predictions on the test set
rf_prediction = rf_classifier.predict(X_test)

# Accuracy
rf_accuracy_score = accuracy_score(y_test, rf_prediction)

# Precision
rf_precision = precision_score(y_test, rf_prediction, average='weighted')

# Recall
rf_recall = recall_score(y_test, rf_prediction, average='weighted')

# F1 score
rf_f1 = f1_score(y_test, rf_prediction, average='weighted')

y_proba = rf_classifier.predict_proba(X_test)[:, 1]
rf_roc_auc = roc_auc_score(y_test, y_proba)

# %%
# Print the metrics
print("Test Accuracy:", rf_accuracy_score)
print("Precision:", rf_precision)
print("Recall:", rf_recall)
print("F1 Score:", rf_f1)
print("ROC AUC Score:", rf_roc_auc)
# Out:
# Test Accuracy: 0.9998944832316269
# Precision: 0.9998945054503611
# Recall: 0.9998944832316269
# F1 Score: 0.9998944832083265
# ROC AUC Score: 0.9999993186713132

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, rf_prediction)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="PiYG", cbar=False,
            xticklabels=['Not Fraud', 'Fraud'], yticklabels=['Not Fraud', 'Fraud'])
plt.title("Confusion Matrix - Random Forest Classifier - Over Sampling")
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Save the plot as an image file (PNG)
plt.savefig('visualization 12.png')
plt.show()

# %%
final_data = pd.DataFrame({'Models':['Logistic Regression','Decision Tree','RandomForest'],
              "ACCURACY":[accuracy_score(y_test,y_prediction)*100,
                     accuracy_score(y_test,y_prediction_dt)*100,
                     accuracy_score(y_test,rf_prediction)*100,
                    ]})
final_data
# Out:
#                 Models   ACCURACY
# 0  Logistic Regression  94.579076
# 1        Decision Tree  97.042013
# 2         RandomForest  99.989448

# %%
# Assuming final_data is a DataFrame containing 'Models' and 'ACCURACY' columns
sns.barplot(x=final_data['Models'], y=final_data['ACCURACY'])
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Models - Over Sampling')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
# Save the plot as an image file (PNG)
plt.savefig('visualization 13.png')
plt.show()

# %% [markdown]
# # **Insight**
#
# *   After over sampling and under sampling, Under sampling is the best method
#     to handle Imbalanced data.
#
#
# *   Random Forest Model has the highest Accuracy. So the best model is Random
#     Forest Model

# %%
# Define model names
model_names = ['Logistic Regression', 'Decision Tree', 'Random Forest']

# Define performance metrics for each model
precisions = [precision, precision_dt, rf_precision]
recalls = [recall, recall_dt, rf_recall]
f1_scores = [f1, f1_dt, rf_f1]
roc_auc_scores = [roc_auc, roc_auc_dt, rf_roc_auc]

# %%
# Plotting
fig, axes = plt.subplots(2, 2, figsize=(16, 18))

# Precision
axes[0, 0].bar(model_names, precisions, color='skyblue')
axes[0, 0].set_title('Precision')
axes[0, 0].set_ylabel('Precision')
axes[0, 0].set_ylim(0, 1)

# Recall
axes[0, 1].bar(model_names, recalls, color='lightgreen')
axes[0, 1].set_title('Recall')
axes[0, 1].set_ylabel('Recall')
axes[0, 1].set_ylim(0, 1)

# F1-score
axes[1, 0].bar(model_names, f1_scores, color='salmon')
axes[1, 0].set_title('F1-score')
axes[1, 0].set_ylabel('F1-score')
axes[1, 0].set_ylim(0, 1)

# ROC-AUC
axes[1, 1].bar(model_names, roc_auc_scores, color='gold')
axes[1, 1].set_title('ROC-AUC')
axes[1, 1].set_ylabel('ROC-AUC')
axes[1, 1].set_ylim(0, 1)

# Adjust layout
plt.tight_layout()
# Save the plot as an image file (PNG)
plt.savefig('visualization 14.png')
plt.show()

# %%
importances = rf_classifier.feature_importances_
feature_names = X.columns  # Assuming X is your feature matrix
importance_dict = dict(zip(feature_names, importances))
sorted_importance_dict = dict(sorted(importance_dict.items(), key=lambda x: x[1], reverse=True))

# %%
import matplotlib.pyplot as plt

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(len(importances)), importances, tick_label=feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Random Forest Feature Importance')
plt.show()
# Save the plot as an image file (PNG)
plt.savefig('feature importance visualization.png')

# %%
# Model Evaluation
from sklearn.metrics import classification_report
print(classification_report(y_test, rf_prediction, target_names=['Not Fraud','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     56750
#        Fraud       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %%
from joblib import dump
import os

# Directory path
directory = 'C:\\Users\\User\\Downloads\\creditcardfrauddetection\\models'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Specify the file path including the file name
file_path = os.path.join(directory, 'random_forest_classifier.joblib')

# %%
# Save the trained Random Forest classifier
dump(rf_classifier, directory)

# Print the saved file path
print("Model saved at:", file_path)
# Out:
# Model saved at: C:\Users\User\Downloads\creditcardfrauddetection\models/random_forest_classifier.joblib
